# %%
import os
import pandas as pd 
import numpy as np 
from tqdm import tqdm
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import metrics
from matplotlib import pyplot as plt
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
import seaborn as sns
from imblearn.over_sampling import RandomOverSampler


BASE_DIR = r"C:\Users\Keelan.Butler\Desktop\python_projects\Final Project"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
ROUTE_DIR = r"C:\Users\Keelan.Butler\Desktop\python_projects\Final Project"
DATA_DIR = os.path.join(ROUTE_DIR,"Sentry-AI","Python")
FEATURE_PATH = os.path.join(BASE_DIR,"Dataset","features")
os.chdir(DATA_DIR)
df_train, df_test = pd.read_csv('Train_set.csv'),pd.read_csv('Test_set.csv')
# load features 
df_train_new, df_val = train_test_split(df_train, test_size=0.05, stratify=df_train['Anomaly_Type'], random_state=42)

def load_features(dataframe):
    """Function extracts features from dataframe and processes them for modelling.
    returns: features, anomaly, anomaly_bool, frame_number
    Arg:
    - dataframe: This will be our test/train dataset. 
    Returns: 
    - Features: Loaded features from corresponding npy file. 
    - anon_type: A break down on what anomaly has occured, otherwise Normal. 
    - anon_bool: A boolean of anomaly occurance.
    - start_frame: List of the corresponding final frame of the sliding window
    - end_frame: List of the corresponding final frame of the sliding window
    - video_names: List of video names, this enables up to partition by videos.
    """
    features = []
    anon_type = []
    anon_bool = []
    start_index = []
    end_index = []
    video_names = []
    for path,subdir, label, lab_bool, clip_start, clip_end, video_name in tqdm(zip(dataframe['feature_path'],dataframe['subfolder'], dataframe['Anomaly_Type'], dataframe['Anomaly'], dataframe['Start_of_Clip'], dataframe['End_of_Clip'], dataframe['name'])):
        feature = np.load(os.path.join(FEATURE_PATH,subdir,path)) # Accesses the relevant path through our relational database 
        features.append(feature) # List of loaded npy features.
        anon_type.append(label) # List of type of anomalies. 
        anon_bool.append(lab_bool) # 1 for anomaly, 0 for normal.
        video_names.append(video_name) # List of video names.
        start_index.append(clip_start) # List of clip start frame
        end_index.append(clip_end) # List of clip start frame
    return features, anon_type, anon_bool, start_index,end_index, video_names

train_features, train_anon_type, train_anon_bool, train_start_index,train_end_index, train_video_names = load_features(df_train_new)
val_features, val_anon_type, val_anon_bool, val_start_index,val_end_index, val_video_names = load_features(df_val)
test_features, test_anon_type, test_anon_bool, test_start_index, test_end_index, test_video_names = load_features(df_test)

def oversample_minority_classes(features, labels, random_state=42):
    ros = RandomOverSampler(sampling_strategy='auto', random_state=random_state)
    features_resampled, labels_resampled = ros.fit_resample(np.array(features), np.array(labels))
    return features_resampled, labels_resampled

train_features_oversampled, train_anon_type_oversampled = oversample_minority_classes(train_features, train_anon_type)

val_features, val_anon_type = oversample_minority_classes(val_features, val_anon_type)

train_features, train_anon_type = train_features_oversampled, train_anon_type_oversampled

l_encoder = LabelEncoder()
train_anon_type = l_encoder.fit_transform(train_anon_type)
val_anon_type = l_encoder.transform(val_anon_type)
test_anon_type = l_encoder.transform(test_anon_type)

class CLIP_DATA(Dataset):
    """Dataset class for clip-based video anomaly detection"""

    def __init__(self, features, anon_label, anon_bool):
        self.features = [torch.from_numpy(arr).float() for arr in features]  # Convert once
        self.anon_label = torch.tensor(anon_label, dtype=torch.long)  # Label-encoded anomaly type
        self.anon_bool = torch.tensor(anon_bool, dtype=torch.float32)  # Binary anomaly indicator (0 or 1)

    def __len__(self):
        return len(self.features) 

    def __getitem__(self, idx):
        return self.features[idx], self.anon_label[idx], self.anon_bool[idx]


training_data = CLIP_DATA(train_features, train_anon_type, train_anon_bool)
validation_data = CLIP_DATA(val_features, val_anon_type, val_anon_bool)
test_data = CLIP_DATA(test_features, test_anon_type, test_anon_bool)

train_dataloader = DataLoader(training_data, batch_size=64, shuffle=False)
validation_dataloader = DataLoader(training_data, batch_size=64, shuffle=False)
test_dataloader = DataLoader(test_data, batch_size=64, shuffle=False)
# Out:
# cpu
# 50540it [02:28, 339.85it/s]
# 2661it [00:07, 356.82it/s]
# 25670it [01:05, 391.69it/s]

# %%
X_train = np.array(train_features)
X_test = np.array(test_features)
X_val = np.array(val_features)

# %%
X_train.shape
# Out:
# (494616, 512)

# %%
# %%time
model = XGBClassifier(
    n_estimators=1000,
    verbosity=2,        # 0 = silent, 1 = warning, 2 = info
    early_stopping_rounds = 10,
    learning_rate = 0.01,
    eval_metric ='mlogloss',
    
)

model.fit(X_train, train_anon_type, eval_set=[(X_test, test_anon_type)])
# Out:
# [15:42:48] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (494616, 512, 253243392).
# [15:42:48] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (25670, 512, 13143040).
# [0]	validation_0-mlogloss:2.46654
# [1]	validation_0-mlogloss:2.44901
# [2]	validation_0-mlogloss:2.43220
# [3]	validation_0-mlogloss:2.41605
# [4]	validation_0-mlogloss:2.39977
# [5]	validation_0-mlogloss:2.38435
# [6]	validation_0-mlogloss:2.36972
# [7]	validation_0-mlogloss:2.35702
# [8]	validation_0-mlogloss:2.34278
# [9]	validation_0-mlogloss:2.32999
# [10]	validation_0-mlogloss:2.31848
# [11]	validation_0-mlogloss:2.30685
# [12]	validation_0-mlogloss:2.29457
# [13]	validation_0-mlogloss:2.28413
# [14]	validation_0-mlogloss:2.27349
# [15]	validation_0-mlogloss:2.26357
# [16]	validation_0-mlogloss:2.25361
# [17]	validation_0-mlogloss:2.24430
# [18]	validation_0-mlogloss:2.23482
# [19]	validation_0-mlogloss:2.22617
# [20]	validation_0-mlogloss:2.21714
# [21]	validation_0-mlogloss:2.20909
# [22]	validation_0-mlogloss:2.20077
# [23]	validation_0-mlogloss:2.19118
# [24]	validation_0-mlogloss:2.18165
# [25]	validation_0-mlogloss:2.17231
# [26]	validation_0-mlogloss:2.16199
# [27]	validation_0-mlogloss:2.15196
# [28]	validation_0-mlogloss:2.14197
# [29]	validation_0-mlogloss:2.13235
# [30]	validation_0-mlogloss:2.12458
# [31]	validation_0-mlogloss:2.11564
# [32]	validation_0-mlogloss:2.10722
# [33]	validation_0-mlogloss:2.09880
# [34]	validation_0-mlogloss:2.09059
# [35]	validation_0-mlogloss:2.08217
# [36]	validation_0-mlogloss:2.07380
# [37]	validation_0-mlogloss:2.06479
# [38]	validation_0-mlogloss:2.05600
# [39]	validation_0-mlogloss:2.04781
# [40]	validation_0-mlogloss:2.03937
# [41]	validation_0-mlogloss:2.03117
# [42]	validation_0-mlogloss:2.02301
# [43]	validation_0-mlogloss:2.01493
# [44]	validation_0-mlogloss:2.00720
# [45]	validation_0-mlogloss:1.99896
# [46]	validation_0-mlogloss:1.99105
# [47]	validation_0-mlogloss:1.98338
# [48]	validation_0-mlogloss:1.97572
# [49]	validation_0-mlogloss:1.96802
# [50]	validation_0-mlogloss:1.96134
# [51]	validation_0-mlogloss:1.95444
# [52]	validation_0-mlogloss:1.94720
# [53]	validation_0-mlogloss:1.94062
# [54]	validation_0-mlogloss:1.93312
# [55]	validation_0-mlogloss:1.92621
# [56]	validation_0-mlogloss:1.91940
# [57]	validation_0-mlogloss:1.91281
# [58]	validation_0-mlogloss:1.90608
# [59]	validation_0-mlogloss:1.90001
# [60]	validation_0-mlogloss:1.89315
# [61]	validation_0-mlogloss:1.88628
# [62]	validation_0-mlogloss:1.87997
# [63]	validation_0-mlogloss:1.87390
# [64]	validation_0-mlogloss:1.86757
# [65]	validation_0-mlogloss:1.86125
# [66]	validation_0-mlogloss:1.85503
# [67]	validation_0-mlogloss:1.84893
# [68]	validation_0-mlogloss:1.84320
# [69]	validation_0-mlogloss:1.83743
# [70]	validation_0-mlogloss:1.83144
# [71]	validation_0-mlogloss:1.82547
# [72]	validation_0-mlogloss:1.81981
# [73]	validation_0-mlogloss:1.81426
# [74]	validation_0-mlogloss:1.80874
# [75]	validation_0-mlogloss:1.80331
# [76]	validation_0-mlogloss:1.79791
# [77]	validation_0-mlogloss:1.79233
# [78]	validation_0-mlogloss:1.78731
# [79]	validation_0-mlogloss:1.78172
# [80]	validation_0-mlogloss:1.77644
# [81]	validation_0-mlogloss:1.77118
# [82]	validation_0-mlogloss:1.76611
# [83]	validation_0-mlogloss:1.76034
# [84]	validation_0-mlogloss:1.75473
# [85]	validation_0-mlogloss:1.74941
# [86]	validation_0-mlogloss:1.74427
# [87]	validation_0-mlogloss:1.73870
# [88]	validation_0-mlogloss:1.73385
# [89]	validation_0-mlogloss:1.72866
# [90]	validation_0-mlogloss:1.72353
# [91]	validation_0-mlogloss:1.71862
# [92]	validation_0-mlogloss:1.71364
# [93]	validation_0-mlogloss:1.70907
# [94]	validation_0-mlogloss:1.70412
# [95]	validation_0-mlogloss:1.69932
# [96]	validation_0-mlogloss:1.69454
# [97]	validation_0-mlogloss:1.69005
# [98]	validation_0-mlogloss:1.68525
# [99]	validation_0-mlogloss:1.68078
# [100]	validation_0-mlogloss:1.67635
# [101]	validation_0-mlogloss:1.67136
# [102]	validation_0-mlogloss:1.66728
# [103]	validation_0-mlogloss:1.66249
# [104]	validation_0-mlogloss:1.65815
# [105]	validation_0-mlogloss:1.65350
# [106]	validation_0-mlogloss:1.64936
# [107]	validation_0-mlogloss:1.64444
# [108]	validation_0-mlogloss:1.64022
# [109]	validation_0-mlogloss:1.63578
# [110]	validation_0-mlogloss:1.63150
# [111]	validation_0-mlogloss:1.62729
# [112]	validation_0-mlogloss:1.62341
# [113]	validation_0-mlogloss:1.61897
# [114]	validation_0-mlogloss:1.61463
# [115]	validation_0-mlogloss:1.61064
# [116]	validation_0-mlogloss:1.60628
# [117]	validation_0-mlogloss:1.60197
# [118]	validation_0-mlogloss:1.59785
# [119]	validation_0-mlogloss:1.59360
# [120]	validation_0-mlogloss:1.58974
# [121]	validation_0-mlogloss:1.58572
# [122]	validation_0-mlogloss:1.58147
# [123]	validation_0-mlogloss:1.57761
# [124]	validation_0-mlogloss:1.57410
# [125]	validation_0-mlogloss:1.57016
# [126]	validation_0-mlogloss:1.56653
# [127]	validation_0-mlogloss:1.56286
# [128]	validation_0-mlogloss:1.55918
# [129]	validation_0-mlogloss:1.55513
# [130]	validation_0-mlogloss:1.55172
# [131]	validation_0-mlogloss:1.54838
# [132]	validation_0-mlogloss:1.54440
# [133]	validation_0-mlogloss:1.54044
# [134]	validation_0-mlogloss:1.53638
# [135]	validation_0-mlogloss:1.53296
# [136]	validation_0-mlogloss:1.52948
# [137]	validation_0-mlogloss:1.52591
# [138]	validation_0-mlogloss:1.52257
# [139]	validation_0-mlogloss:1.51919
# [140]	validation_0-mlogloss:1.51537
# [141]	validation_0-mlogloss:1.51186
# [142]	validation_0-mlogloss:1.50866
# [143]	validation_0-mlogloss:1.50559
# [144]	validation_0-mlogloss:1.50251
# [145]	validation_0-mlogloss:1.49930
# [146]	validation_0-mlogloss:1.49598
# [147]	validation_0-mlogloss:1.49289
# [148]	validation_0-mlogloss:1.48956
# [149]	validation_0-mlogloss:1.48634
# [150]	validation_0-mlogloss:1.48352
# [151]	validation_0-mlogloss:1.48058
# [152]	validation_0-mlogloss:1.47781
# [153]	validation_0-mlogloss:1.47456
# [154]	validation_0-mlogloss:1.47171
# [155]	validation_0-mlogloss:1.46877
# [156]	validation_0-mlogloss:1.46647
# [157]	validation_0-mlogloss:1.46342
# [158]	validation_0-mlogloss:1.46064
# [159]	validation_0-mlogloss:1.45802
# [160]	validation_0-mlogloss:1.45511
# [161]	validation_0-mlogloss:1.45235
# [162]	validation_0-mlogloss:1.44932
# [163]	validation_0-mlogloss:1.44658
# [164]	validation_0-mlogloss:1.44385
# [165]	validation_0-mlogloss:1.44122
# [166]	validation_0-mlogloss:1.43804
# [167]	validation_0-mlogloss:1.43544
# [168]	validation_0-mlogloss:1.43258
# [169]	validation_0-mlogloss:1.42990
# [170]	validation_0-mlogloss:1.42689
# [171]	validation_0-mlogloss:1.42427
# [172]	validation_0-mlogloss:1.42127
# [173]	validation_0-mlogloss:1.41848
# [174]	validation_0-mlogloss:1.41571
# [175]	validation_0-mlogloss:1.41319
# [176]	validation_0-mlogloss:1.41042
# [177]	validation_0-mlogloss:1.40787
# [178]	validation_0-mlogloss:1.40502
# [179]	validation_0-mlogloss:1.40265
# [180]	validation_0-mlogloss:1.39960
# [181]	validation_0-mlogloss:1.39713
# [182]	validation_0-mlogloss:1.39410
# [183]	validation_0-mlogloss:1.39175
# [184]	validation_0-mlogloss:1.38930
# [185]	validation_0-mlogloss:1.38626
# [186]	validation_0-mlogloss:1.38396
# [187]	validation_0-mlogloss:1.38149
# [188]	validation_0-mlogloss:1.37898
# [189]	validation_0-mlogloss:1.37648
# [190]	validation_0-mlogloss:1.37396
# [191]	validation_0-mlogloss:1.37173
# [192]	validation_0-mlogloss:1.36929
# [193]	validation_0-mlogloss:1.36701
# [194]	validation_0-mlogloss:1.36464
# [195]	validation_0-mlogloss:1.36220
# [196]	validation_0-mlogloss:1.35951
# [197]	validation_0-mlogloss:1.35718
# [198]	validation_0-mlogloss:1.35481
# [199]	validation_0-mlogloss:1.35249
# [200]	validation_0-mlogloss:1.35015
# [201]	validation_0-mlogloss:1.34765
# [202]	validation_0-mlogloss:1.34537
# [203]	validation_0-mlogloss:1.34323
# [204]	validation_0-mlogloss:1.34085
# [205]	validation_0-mlogloss:1.33864
# [206]	validation_0-mlogloss:1.33635
# [207]	validation_0-mlogloss:1.33410
# [208]	validation_0-mlogloss:1.33204
# [209]	validation_0-mlogloss:1.32991
# [210]	validation_0-mlogloss:1.32754
# [211]	validation_0-mlogloss:1.32536
# [212]	validation_0-mlogloss:1.32318
# [213]	validation_0-mlogloss:1.32093
# [214]	validation_0-mlogloss:1.31877
# [215]	validation_0-mlogloss:1.31682
# [216]	validation_0-mlogloss:1.31468
# [217]	validation_0-mlogloss:1.31243
# [218]	validation_0-mlogloss:1.31033
# [219]	validation_0-mlogloss:1.30805
# [220]	validation_0-mlogloss:1.30593
# [221]	validation_0-mlogloss:1.30375
# [222]	validation_0-mlogloss:1.30152
# [223]	validation_0-mlogloss:1.29937
# [224]	validation_0-mlogloss:1.29727
# [225]	validation_0-mlogloss:1.29528
# [226]	validation_0-mlogloss:1.29327
# [227]	validation_0-mlogloss:1.29108
# [228]	validation_0-mlogloss:1.28901
# [229]	validation_0-mlogloss:1.28716
# [230]	validation_0-mlogloss:1.28508
# [231]	validation_0-mlogloss:1.28322
# [232]	validation_0-mlogloss:1.28150
# [233]	validation_0-mlogloss:1.27938
# [234]	validation_0-mlogloss:1.27741
# [235]	validation_0-mlogloss:1.27553
# [236]	validation_0-mlogloss:1.27373
# [237]	validation_0-mlogloss:1.27199
# [238]	validation_0-mlogloss:1.27023
# [239]	validation_0-mlogloss:1.26841
# [240]	validation_0-mlogloss:1.26647
# [241]	validation_0-mlogloss:1.26479
# [242]	validation_0-mlogloss:1.26270
# [243]	validation_0-mlogloss:1.26108
# [244]	validation_0-mlogloss:1.25936
# [245]	validation_0-mlogloss:1.25746
# [246]	validation_0-mlogloss:1.25570
# [247]	validation_0-mlogloss:1.25379
# [248]	validation_0-mlogloss:1.25207
# [249]	validation_0-mlogloss:1.25037
# [250]	validation_0-mlogloss:1.24854
# [251]	validation_0-mlogloss:1.24679
# [252]	validation_0-mlogloss:1.24494
# [253]	validation_0-mlogloss:1.24299
# [254]	validation_0-mlogloss:1.24108
# [255]	validation_0-mlogloss:1.23921
# [256]	validation_0-mlogloss:1.23762
# [257]	validation_0-mlogloss:1.23571
# [258]	validation_0-mlogloss:1.23375
# [259]	validation_0-mlogloss:1.23204
# [260]	validation_0-mlogloss:1.23019
# [261]	validation_0-mlogloss:1.22823
# [262]	validation_0-mlogloss:1.22626
# [263]	validation_0-mlogloss:1.22460
# [264]	validation_0-mlogloss:1.22278
# [265]	validation_0-mlogloss:1.22093
# [266]	validation_0-mlogloss:1.21914
# [267]	validation_0-mlogloss:1.21759
# [268]	validation_0-mlogloss:1.21574
# [269]	validation_0-mlogloss:1.21399
# [270]	validation_0-mlogloss:1.21210
# [271]	validation_0-mlogloss:1.21034
# [272]	validation_0-mlogloss:1.20876
# [273]	validation_0-mlogloss:1.20710
# [274]	validation_0-mlogloss:1.20548
# [275]	validation_0-mlogloss:1.20403
# [276]	validation_0-mlogloss:1.20245
# [277]	validation_0-mlogloss:1.20078
# [278]	validation_0-mlogloss:1.19925
# [279]	validation_0-mlogloss:1.19743
# [280]	validation_0-mlogloss:1.19589
# [281]	validation_0-mlogloss:1.19420
# [282]	validation_0-mlogloss:1.19288
# [283]	validation_0-mlogloss:1.19140
# [284]	validation_0-mlogloss:1.18966
# [285]	validation_0-mlogloss:1.18833
# [286]	validation_0-mlogloss:1.18690
# [287]	validation_0-mlogloss:1.18540
# [288]	validation_0-mlogloss:1.18413
# [289]	validation_0-mlogloss:1.18261
# [290]	validation_0-mlogloss:1.18118
# [291]	validation_0-mlogloss:1.17986
# [292]	validation_0-mlogloss:1.17822
# [293]	validation_0-mlogloss:1.17676
# [294]	validation_0-mlogloss:1.17521
# [295]	validation_0-mlogloss:1.17374
# [296]	validation_0-mlogloss:1.17222
# [297]	validation_0-mlogloss:1.17068
# [298]	validation_0-mlogloss:1.16940
# [299]	validation_0-mlogloss:1.16789
# [300]	validation_0-mlogloss:1.16645
# [301]	validation_0-mlogloss:1.16490
# [302]	validation_0-mlogloss:1.16336
# [303]	validation_0-mlogloss:1.16196
# [304]	validation_0-mlogloss:1.16056
# [305]	validation_0-mlogloss:1.15942
# [306]	validation_0-mlogloss:1.15795
# [307]	validation_0-mlogloss:1.15662
# [308]	validation_0-mlogloss:1.15522
# [309]	validation_0-mlogloss:1.15382
# [310]	validation_0-mlogloss:1.15265
# [311]	validation_0-mlogloss:1.15139
# [312]	validation_0-mlogloss:1.15020
# [313]	validation_0-mlogloss:1.14901
# [314]	validation_0-mlogloss:1.14782
# [315]	validation_0-mlogloss:1.14658
# [316]	validation_0-mlogloss:1.14541
# [317]	validation_0-mlogloss:1.14414
# [318]	validation_0-mlogloss:1.14297
# [319]	validation_0-mlogloss:1.14187
# [320]	validation_0-mlogloss:1.14087
# [321]	validation_0-mlogloss:1.13956
# [322]	validation_0-mlogloss:1.13836
# [323]	validation_0-mlogloss:1.13726
# [324]	validation_0-mlogloss:1.13608
# [325]	validation_0-mlogloss:1.13486
# [326]	validation_0-mlogloss:1.13373
# [327]	validation_0-mlogloss:1.13272
# [328]	validation_0-mlogloss:1.13151
# [329]	validation_0-mlogloss:1.13041
# [330]	validation_0-mlogloss:1.12925
# [331]	validation_0-mlogloss:1.12799
# [332]	validation_0-mlogloss:1.12698
# [333]	validation_0-mlogloss:1.12604
# [334]	validation_0-mlogloss:1.12489
# [335]	validation_0-mlogloss:1.12378
# [336]	validation_0-mlogloss:1.12251
# [337]	validation_0-mlogloss:1.12147
# [338]	validation_0-mlogloss:1.12042
# [339]	validation_0-mlogloss:1.11949
# [340]	validation_0-mlogloss:1.11841
# [341]	validation_0-mlogloss:1.11735
# [342]	validation_0-mlogloss:1.11632
# [343]	validation_0-mlogloss:1.11526
# [344]	validation_0-mlogloss:1.11421
# [345]	validation_0-mlogloss:1.11332
# [346]	validation_0-mlogloss:1.11248
# [347]	validation_0-mlogloss:1.11141
# [348]	validation_0-mlogloss:1.11047
# [349]	validation_0-mlogloss:1.10960
# [350]	validation_0-mlogloss:1.10861
# [351]	validation_0-mlogloss:1.10749
# [352]	validation_0-mlogloss:1.10641
# [353]	validation_0-mlogloss:1.10546
# [354]	validation_0-mlogloss:1.10458
# [355]	validation_0-mlogloss:1.10365
# [356]	validation_0-mlogloss:1.10281
# [357]	validation_0-mlogloss:1.10182
# [358]	validation_0-mlogloss:1.10086
# [359]	validation_0-mlogloss:1.10010
# [360]	validation_0-mlogloss:1.09941
# [361]	validation_0-mlogloss:1.09860
# [362]	validation_0-mlogloss:1.09775
# [363]	validation_0-mlogloss:1.09690
# [364]	validation_0-mlogloss:1.09608
# [365]	validation_0-mlogloss:1.09511
# [366]	validation_0-mlogloss:1.09430
# [367]	validation_0-mlogloss:1.09347
# [368]	validation_0-mlogloss:1.09287
# [369]	validation_0-mlogloss:1.09215
# [370]	validation_0-mlogloss:1.09124
# [371]	validation_0-mlogloss:1.09069
# [372]	validation_0-mlogloss:1.08992
# [373]	validation_0-mlogloss:1.08936
# [374]	validation_0-mlogloss:1.08868
# [375]	validation_0-mlogloss:1.08787
# [376]	validation_0-mlogloss:1.08723
# [377]	validation_0-mlogloss:1.08645
# [378]	validation_0-mlogloss:1.08585
# [379]	validation_0-mlogloss:1.08510
# [380]	validation_0-mlogloss:1.08438
# [381]	validation_0-mlogloss:1.08378
# [382]	validation_0-mlogloss:1.08306
# [383]	validation_0-mlogloss:1.08239
# [384]	validation_0-mlogloss:1.08167
# [385]	validation_0-mlogloss:1.08104
# [386]	validation_0-mlogloss:1.08049
# [387]	validation_0-mlogloss:1.07977
# [388]	validation_0-mlogloss:1.07901
# [389]	validation_0-mlogloss:1.07837
# [390]	validation_0-mlogloss:1.07766
# [391]	validation_0-mlogloss:1.07698
# [392]	validation_0-mlogloss:1.07636
# [393]	validation_0-mlogloss:1.07573
# [394]	validation_0-mlogloss:1.07517
# [395]	validation_0-mlogloss:1.07450
# [396]	validation_0-mlogloss:1.07393
# [397]	validation_0-mlogloss:1.07327
# [398]	validation_0-mlogloss:1.07266
# [399]	validation_0-mlogloss:1.07200
# [400]	validation_0-mlogloss:1.07134
# [401]	validation_0-mlogloss:1.07078
# [402]	validation_0-mlogloss:1.07020
# [403]	validation_0-mlogloss:1.06967
# [404]	validation_0-mlogloss:1.06915
# [405]	validation_0-mlogloss:1.06865
# [406]	validation_0-mlogloss:1.06815
# [407]	validation_0-mlogloss:1.06760
# [408]	validation_0-mlogloss:1.06710
# [409]	validation_0-mlogloss:1.06670
# [410]	validation_0-mlogloss:1.06621
# [411]	validation_0-mlogloss:1.06567
# [412]	validation_0-mlogloss:1.06515
# [413]	validation_0-mlogloss:1.06469
# [414]	validation_0-mlogloss:1.06417
# [415]	validation_0-mlogloss:1.06366
# [416]	validation_0-mlogloss:1.06308
# [417]	validation_0-mlogloss:1.06265
# [418]	validation_0-mlogloss:1.06210
# [419]	validation_0-mlogloss:1.06168
# [420]	validation_0-mlogloss:1.06131
# [421]	validation_0-mlogloss:1.06092
# [422]	validation_0-mlogloss:1.06048
# [423]	validation_0-mlogloss:1.05996
# [424]	validation_0-mlogloss:1.05962
# [425]	validation_0-mlogloss:1.05917
# [426]	validation_0-mlogloss:1.05875
# [427]	validation_0-mlogloss:1.05833
# [428]	validation_0-mlogloss:1.05776
# [429]	validation_0-mlogloss:1.05745
# [430]	validation_0-mlogloss:1.05714
# [431]	validation_0-mlogloss:1.05691
# [432]	validation_0-mlogloss:1.05650
# [433]	validation_0-mlogloss:1.05612
# [434]	validation_0-mlogloss:1.05566
# [435]	validation_0-mlogloss:1.05535
# [436]	validation_0-mlogloss:1.05510
# [437]	validation_0-mlogloss:1.05453
# [438]	validation_0-mlogloss:1.05418
# [439]	validation_0-mlogloss:1.05387
# [440]	validation_0-mlogloss:1.05350
# [441]	validation_0-mlogloss:1.05312
# [442]	validation_0-mlogloss:1.05259
# [443]	validation_0-mlogloss:1.05229
# [444]	validation_0-mlogloss:1.05190
# [445]	validation_0-mlogloss:1.05156
# [446]	validation_0-mlogloss:1.05123
# [447]	validation_0-mlogloss:1.05096
# [448]	validation_0-mlogloss:1.05053
# [449]	validation_0-mlogloss:1.05018
# [450]	validation_0-mlogloss:1.04973
# [451]	validation_0-mlogloss:1.04946
# [452]	validation_0-mlogloss:1.04922
# [453]	validation_0-mlogloss:1.04890
# [454]	validation_0-mlogloss:1.04850
# [455]	validation_0-mlogloss:1.04810
# [456]	validation_0-mlogloss:1.04784
# [457]	validation_0-mlogloss:1.04745
# [458]	validation_0-mlogloss:1.04719
# [459]	validation_0-mlogloss:1.04703
# [460]	validation_0-mlogloss:1.04669
# [461]	validation_0-mlogloss:1.04634
# [462]	validation_0-mlogloss:1.04616
# [463]	validation_0-mlogloss:1.04594
# [464]	validation_0-mlogloss:1.04561
# [465]	validation_0-mlogloss:1.04518
# [466]	validation_0-mlogloss:1.04493
# [467]	validation_0-mlogloss:1.04475
# [468]	validation_0-mlogloss:1.04451
# [469]	validation_0-mlogloss:1.04419
# [470]	validation_0-mlogloss:1.04408
# [471]	validation_0-mlogloss:1.04377
# [472]	validation_0-mlogloss:1.04349
# [473]	validation_0-mlogloss:1.04327
# [474]	validation_0-mlogloss:1.04302
# [475]	validation_0-mlogloss:1.04281
# [476]	validation_0-mlogloss:1.04268
# [477]	validation_0-mlogloss:1.04246
# [478]	validation_0-mlogloss:1.04220
# [479]	validation_0-mlogloss:1.04204
# [480]	validation_0-mlogloss:1.04174
# [481]	validation_0-mlogloss:1.04157
# [482]	validation_0-mlogloss:1.04146
# [483]	validation_0-mlogloss:1.04126
# [484]	validation_0-mlogloss:1.04118
# [485]	validation_0-mlogloss:1.04090
# [486]	validation_0-mlogloss:1.04079
# [487]	validation_0-mlogloss:1.04067
# [488]	validation_0-mlogloss:1.04050
# [489]	validation_0-mlogloss:1.04040
# [490]	validation_0-mlogloss:1.04025
# [491]	validation_0-mlogloss:1.03998
# [492]	validation_0-mlogloss:1.03982
# [493]	validation_0-mlogloss:1.03969
# [494]	validation_0-mlogloss:1.03958
# [495]	validation_0-mlogloss:1.03940
# [496]	validation_0-mlogloss:1.03916
# [497]	validation_0-mlogloss:1.03902
# [498]	validation_0-mlogloss:1.03883
# [499]	validation_0-mlogloss:1.03870
# [500]	validation_0-mlogloss:1.03859
# [501]	validation_0-mlogloss:1.03843
# [502]	validation_0-mlogloss:1.03825
# [503]	validation_0-mlogloss:1.03808
# [504]	validation_0-mlogloss:1.03793
# [505]	validation_0-mlogloss:1.03774
# [506]	validation_0-mlogloss:1.03756
# [507]	validation_0-mlogloss:1.03741
# [508]	validation_0-mlogloss:1.03726
# [509]	validation_0-mlogloss:1.03716
# [510]	validation_0-mlogloss:1.03709
# [511]	validation_0-mlogloss:1.03694
# [512]	validation_0-mlogloss:1.03686
# [513]	validation_0-mlogloss:1.03665
# [514]	validation_0-mlogloss:1.03648
# [515]	validation_0-mlogloss:1.03629
# [516]	validation_0-mlogloss:1.03608
# [517]	validation_0-mlogloss:1.03597
# [518]	validation_0-mlogloss:1.03580
# [519]	validation_0-mlogloss:1.03562
# [520]	validation_0-mlogloss:1.03556
# [521]	validation_0-mlogloss:1.03548
# [522]	validation_0-mlogloss:1.03521
# [523]	validation_0-mlogloss:1.03502
# [524]	validation_0-mlogloss:1.03490
# [525]	validation_0-mlogloss:1.03487
# [526]	validation_0-mlogloss:1.03478
# [527]	validation_0-mlogloss:1.03467
# [528]	validation_0-mlogloss:1.03442
# [529]	validation_0-mlogloss:1.03441
# [530]	validation_0-mlogloss:1.03438
# [531]	validation_0-mlogloss:1.03427
# [532]	validation_0-mlogloss:1.03415
# [533]	validation_0-mlogloss:1.03405
# [534]	validation_0-mlogloss:1.03408
# [535]	validation_0-mlogloss:1.03401
# [536]	validation_0-mlogloss:1.03402
# [537]	validation_0-mlogloss:1.03398
# [538]	validation_0-mlogloss:1.03384
# [539]	validation_0-mlogloss:1.03384
# [540]	validation_0-mlogloss:1.03385
# [541]	validation_0-mlogloss:1.03376
# [542]	validation_0-mlogloss:1.03376
# [543]	validation_0-mlogloss:1.03359
# [544]	validation_0-mlogloss:1.03364
# [545]	validation_0-mlogloss:1.03352
# [546]	validation_0-mlogloss:1.03345
# [547]	validation_0-mlogloss:1.03343
# [548]	validation_0-mlogloss:1.03341
# [549]	validation_0-mlogloss:1.03343
# [550]	validation_0-mlogloss:1.03346
# [551]	validation_0-mlogloss:1.03340
# [552]	validation_0-mlogloss:1.03341
# [553]	validation_0-mlogloss:1.03335
# [554]	validation_0-mlogloss:1.03342
# [555]	validation_0-mlogloss:1.03334
# [556]	validation_0-mlogloss:1.03333
# [557]	validation_0-mlogloss:1.03332
# [558]	validation_0-mlogloss:1.03330
# [559]	validation_0-mlogloss:1.03331
# [560]	validation_0-mlogloss:1.03321
# [561]	validation_0-mlogloss:1.03320
# [562]	validation_0-mlogloss:1.03330
# [563]	validation_0-mlogloss:1.03335
# [564]	validation_0-mlogloss:1.03331
# [565]	validation_0-mlogloss:1.03341
# [566]	validation_0-mlogloss:1.03344
# [567]	validation_0-mlogloss:1.03355
# [568]	validation_0-mlogloss:1.03376
# [569]	validation_0-mlogloss:1.03386
# [570]	validation_0-mlogloss:1.03395
# [571]	validation_0-mlogloss:1.03407
# CPU times: total: 14h 55min 30s
# Wall time: 2h 11min 58s
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1000, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
print("Initial Model Accuracy:", model.score(X_test, test_anon_type))
print("Initial Model F1 Score:", metrics.f1_score(test_anon_type, model.predict(test_features), average= 'macro'))
# Out:
# Initial Model Accuracy: 0.7282820412933385
# Initial Model F1 Score: 0.15896009383462698

# %%
original_cm = metrics.confusion_matrix(train_anon_type, model.predict(X_train))

class_names = l_encoder.classes_ # Returning class names

plt.figure(figsize=(10, 8))
sns.heatmap(original_cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names, cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
original_cm = metrics.confusion_matrix(test_anon_type, model.predict(X_test))

class_names = l_encoder.classes_ # Returning class names

plt.figure(figsize=(10, 8))
sns.heatmap(original_cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names, cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
# I am recalling the model here so that the training isn't just overfitting
model = XGBClassifier(
    verbosity=2,        # 0 = silent, 1 = warning, 2 = info
    eval_metric='mlogloss'
)

# %%
# Hyperparameter tuning
param_grid = {
    'n_estimators': [500], 
    'learning_rate': [0.01, 0.05 ,0.1],  
    'max_depth': [3, 6, 9],  
}

# %%
search = GridSearchCV(
    model,
    param_grid=param_grid,
    cv=2, 
    scoring='f1_weighted', 
    verbose=2   
)
search.fit(X_val, val_anon_type)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [13:07:38] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (13020, 512, 6666240).
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time= 3.0min
# [13:10:35] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (13020, 512, 6666240).
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time= 3.1min
# [13:13:41] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (13020, 512, 6666240).
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=500; total time= 4.6min
# [13:18:16] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (13020, 512, 6666240).
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=500; total time= 4.6min
# [13:22:49] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (13020, 512, 6666240).
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=500; total time= 5.4min
# [13:28:11] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (13020, 512, 6666240).
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=500; total time= 5.5min
# [13:33:42] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (13020, 512, 6666240).
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=500; total time= 2.7min
# [13:36:23] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (13020, 512, 6666240).
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=500; total time= 2.6min
# [13:38:59] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (13020, 512, 6666240).
# [CV] END ..learning_rate=0.05, max_depth=6, n_estimators=500; total time= 3.0min
# [13:42:02] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (13020, 512, 6666240).
# [CV] END ..learning_rate=0.05, max_depth=6, n_estimators=500; total time= 2.9min
# [13:44:57] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (13020, 512, 6666240).
# [CV] END ..learning_rate=0.05, max_depth=9, n_estimators=500; total time= 3.3min
# [13:48:16] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (13020, 512, 6666240).
# [CV] END ..learning_rate=0.05, max_depth=9, n_estimators=500; total time= 3.2min
# [13:51:28] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (13020, 512, 6666240).
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=500; total time= 1.9min
# [13:53:23] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (13020, 512, 6666240).
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=500; total time= 1.9min
# [13:55:18] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (13020, 512, 6666240).
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=500; total time= 2.1min
# [13:57:23] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (13020, 512, 6666240).
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=500; total time= 2.1min
# [13:59:28] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (13020, 512, 6666240).
# [CV] END ...learning_rate=0.1, max_depth=9, n_estimators=500; total time= 2.3min
# [14:01:48] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (13020, 512, 6666240).
# [CV] END ...learning_rate=0.1, max_depth=9, n_estimators=500; total time= 2.2min
# [14:04:02] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (26040, 512, 13332480).
# GridSearchCV(cv=2,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False,
#                                      eval_metric='mlogloss', feature_types=None,
#                                      feature_weights=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constrain...
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              param_grid={'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [3, 6, 9], 'n_estimators': [500]},
#              scoring='f1_weighted', verbose=2)

# %%
cvgs_results = pd.DataFrame(search.cv_results_)
display(cvgs_results)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0     181.411976      4.071574         0.253266        0.003723
# 1     273.750707      0.544896         0.346788        0.018538
# 2     326.074618      4.242829         0.408436        0.011989
# 3     158.298597      2.175195         0.213321        0.000882
# 4     178.404254      3.835660         0.238805        0.002821
# 5     195.713539      3.681734         0.241654        0.018853
# 6     114.581057      0.043272         0.164197        0.005779
# 7     124.809148      0.214462         0.170107        0.004790
# 8     136.414290      3.593168         0.159945        0.010614
#
#   param_learning_rate param_max_depth param_n_estimators  \
# 0                0.01               3                500
# 1                0.01               6                500
# 2                0.01               9                500
# 3                0.05               3                500
# 4                0.05               6                500
# 5                0.05               9                500
# 6                 0.1               3                500
# 7                 0.1               6                500
# 8                 0.1               9                500
#
#                                               params  split0_test_score  \
# 0  {'learning_rate': 0.01, 'max_depth': 3, 'n_est...           0.995493
# 1  {'learning_rate': 0.01, 'max_depth': 6, 'n_est...           0.997838
# 2  {'learning_rate': 0.01, 'max_depth': 9, 'n_est...           0.998070
# 3  {'learning_rate': 0.05, 'max_depth': 3, 'n_est...           0.998381
# 4  {'learning_rate': 0.05, 'max_depth': 6, 'n_est...           0.998767
# 5  {'learning_rate': 0.05, 'max_depth': 9, 'n_est...           0.998381
# 6  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...           0.998458
# 7  {'learning_rate': 0.1, 'max_depth': 6, 'n_esti...           0.998458
# 8  {'learning_rate': 0.1, 'max_depth': 9, 'n_esti...           0.998381
#
#    split1_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.993761         0.994627        0.000866                9
# 1           0.997916         0.997877        0.000039                8
# 2           0.998226         0.998148        0.000078                7
# 3           0.998922         0.998651        0.000271                5
# 4           0.998999         0.998883        0.000116                1
# 5           0.998922         0.998651        0.000271                4
# 6           0.998922         0.998690        0.000232                2
# 7           0.998845         0.998651        0.000194                6
# 8           0.998922         0.998652        0.000271                3

# %%
model_optimised = XGBClassifier(**search.best_params_,early_stopping_rounds = 10,verbosity = 2)
model_optimised.fit(X_train, train_anon_type, eval_set= [(X_test,test_anon_type)])
# Out:
# [14:08:38] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (494616, 512, 253243392).
# [14:08:39] INFO: C:\actions-runner\_work\xgboost\xgboost\src\data\iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (25670, 512, 13143040).
# [0]	validation_0-mlogloss:2.39489
# [1]	validation_0-mlogloss:2.31720
# [2]	validation_0-mlogloss:2.25735
# [3]	validation_0-mlogloss:2.20950
# [4]	validation_0-mlogloss:2.16453
# [5]	validation_0-mlogloss:2.11955
# [6]	validation_0-mlogloss:2.07541
# [7]	validation_0-mlogloss:2.02967
# [8]	validation_0-mlogloss:1.98712
# [9]	validation_0-mlogloss:1.94980
# [10]	validation_0-mlogloss:1.91607
# [11]	validation_0-mlogloss:1.88243
# [12]	validation_0-mlogloss:1.84903
# [13]	validation_0-mlogloss:1.82037
# [14]	validation_0-mlogloss:1.79078
# [15]	validation_0-mlogloss:1.76385
# [16]	validation_0-mlogloss:1.73844
# [17]	validation_0-mlogloss:1.71395
# [18]	validation_0-mlogloss:1.69166
# [19]	validation_0-mlogloss:1.66819
# [20]	validation_0-mlogloss:1.64528
# [21]	validation_0-mlogloss:1.62341
# [22]	validation_0-mlogloss:1.60379
# [23]	validation_0-mlogloss:1.58412
# [24]	validation_0-mlogloss:1.56602
# [25]	validation_0-mlogloss:1.54592
# [26]	validation_0-mlogloss:1.52765
# [27]	validation_0-mlogloss:1.51015
# [28]	validation_0-mlogloss:1.49242
# [29]	validation_0-mlogloss:1.47544
# [30]	validation_0-mlogloss:1.46204
# [31]	validation_0-mlogloss:1.44793
# [32]	validation_0-mlogloss:1.43418
# [33]	validation_0-mlogloss:1.42086
# [34]	validation_0-mlogloss:1.40782
# [35]	validation_0-mlogloss:1.39423
# [36]	validation_0-mlogloss:1.38129
# [37]	validation_0-mlogloss:1.36940
# [38]	validation_0-mlogloss:1.35831
# [39]	validation_0-mlogloss:1.34745
# [40]	validation_0-mlogloss:1.33470
# [41]	validation_0-mlogloss:1.32317
# [42]	validation_0-mlogloss:1.31233
# [43]	validation_0-mlogloss:1.30083
# [44]	validation_0-mlogloss:1.28933
# [45]	validation_0-mlogloss:1.27942
# [46]	validation_0-mlogloss:1.27012
# [47]	validation_0-mlogloss:1.26153
# [48]	validation_0-mlogloss:1.25142
# [49]	validation_0-mlogloss:1.24339
# [50]	validation_0-mlogloss:1.23394
# [51]	validation_0-mlogloss:1.22456
# [52]	validation_0-mlogloss:1.21591
# [53]	validation_0-mlogloss:1.20709
# [54]	validation_0-mlogloss:1.19743
# [55]	validation_0-mlogloss:1.19037
# [56]	validation_0-mlogloss:1.18247
# [57]	validation_0-mlogloss:1.17537
# [58]	validation_0-mlogloss:1.16852
# [59]	validation_0-mlogloss:1.16167
# [60]	validation_0-mlogloss:1.15480
# [61]	validation_0-mlogloss:1.14853
# [62]	validation_0-mlogloss:1.14248
# [63]	validation_0-mlogloss:1.13638
# [64]	validation_0-mlogloss:1.12986
# [65]	validation_0-mlogloss:1.12464
# [66]	validation_0-mlogloss:1.12002
# [67]	validation_0-mlogloss:1.11457
# [68]	validation_0-mlogloss:1.10918
# [69]	validation_0-mlogloss:1.10453
# [70]	validation_0-mlogloss:1.10017
# [71]	validation_0-mlogloss:1.09665
# [72]	validation_0-mlogloss:1.09303
# [73]	validation_0-mlogloss:1.08926
# [74]	validation_0-mlogloss:1.08581
# [75]	validation_0-mlogloss:1.08254
# [76]	validation_0-mlogloss:1.07880
# [77]	validation_0-mlogloss:1.07652
# [78]	validation_0-mlogloss:1.07289
# [79]	validation_0-mlogloss:1.06965
# [80]	validation_0-mlogloss:1.06634
# [81]	validation_0-mlogloss:1.06413
# [82]	validation_0-mlogloss:1.06085
# [83]	validation_0-mlogloss:1.05888
# [84]	validation_0-mlogloss:1.05666
# [85]	validation_0-mlogloss:1.05520
# [86]	validation_0-mlogloss:1.05375
# [87]	validation_0-mlogloss:1.05223
# [88]	validation_0-mlogloss:1.05004
# [89]	validation_0-mlogloss:1.04856
# [90]	validation_0-mlogloss:1.04742
# [91]	validation_0-mlogloss:1.04623
# [92]	validation_0-mlogloss:1.04514
# [93]	validation_0-mlogloss:1.04413
# [94]	validation_0-mlogloss:1.04325
# [95]	validation_0-mlogloss:1.04215
# [96]	validation_0-mlogloss:1.04173
# [97]	validation_0-mlogloss:1.04138
# [98]	validation_0-mlogloss:1.04094
# [99]	validation_0-mlogloss:1.04058
# [100]	validation_0-mlogloss:1.03940
# [101]	validation_0-mlogloss:1.03892
# [102]	validation_0-mlogloss:1.03871
# [103]	validation_0-mlogloss:1.03777
# [104]	validation_0-mlogloss:1.03684
# [105]	validation_0-mlogloss:1.03672
# [106]	validation_0-mlogloss:1.03643
# [107]	validation_0-mlogloss:1.03582
# [108]	validation_0-mlogloss:1.03605
# [109]	validation_0-mlogloss:1.03595
# [110]	validation_0-mlogloss:1.03518
# [111]	validation_0-mlogloss:1.03475
# [112]	validation_0-mlogloss:1.03508
# [113]	validation_0-mlogloss:1.03613
# [114]	validation_0-mlogloss:1.03654
# [115]	validation_0-mlogloss:1.03741
# [116]	validation_0-mlogloss:1.03777
# [117]	validation_0-mlogloss:1.03836
# [118]	validation_0-mlogloss:1.03908
# [119]	validation_0-mlogloss:1.03976
# [120]	validation_0-mlogloss:1.04024
# [121]	validation_0-mlogloss:1.04153
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=500,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
print("Optimised Model Accuracy:", model_optimised.score(test_features, test_anon_type))
print("Optimised Model F1 Score:", metrics.f1_score(test_anon_type, model_optimised.predict(test_features), average= 'macro'))
# Out:
# Optimised Model Accuracy: 0.7232177639267627
# Optimised Model F1 Score: 0.157587139225284

# %%
optimised_cm = metrics.confusion_matrix(test_anon_type, model_optimised.predict(X_test))
sns.heatmap(optimised_cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names, cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix (Optimised Model)')
plt.show()
